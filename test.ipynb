# %%
import pandas as pd
from pathlib import Path

# %%
data_directory = Path("Data/DER")

# %%
# limit to first 100 sols

# read in pressure data
data_ps = pd.read_csv(data_directory/"DER_PS_SOL_01_100.csv")

# read in realtive humidity sensor
data_rh = pd.read_csv(data_directory/"DER_RHS_SOL_01_100.csv")

# read in Thermal Infra-Red Sensor, TIRS
data_tirs = pd.read_csv(data_directory/"DER_TIRS_SOL_01_100.csv")

# read in ancillary data 
data_ancil = pd.read_csv(data_directory/"DER_ANCILLARY_SOL_01_100.csv")

# %%
data_ps.head()
# Out:
#         SCLK                LMST           LTST  PRESSURE  \
# 0  667042464  00001M16:05:31.315  0001 15:28:01    715.96
# 1  667042465  00001M16:05:32.289  0001 15:28:02    715.82
# 2  667042466  00001M16:05:33.262  0001 15:28:03    715.99
# 3  667042467  00001M16:05:34.235  0001 15:28:04    715.92
# 4  667042468  00001M16:05:35.208  0001 15:28:05    715.77
#
#    PRESSURE_UNCERTAINTY  TRANSDUCER  sol
# 0                   NaN           2    1
# 1                   NaN           2    1
# 2                   NaN           2    1
# 3                   NaN           2    1
# 4                   NaN           2    1

# %%
data_ps.head(300000).plot(x="LMST", y="PRESSURE")
# Out:
# <Axes: xlabel='LMST'>

# %%
data_rh.head(300000).plot(x="LMST", y="HUMIDITY_LOCAL_TEMP")
# Out:
# <Axes: xlabel='LMST'>

# %%
data_tirs.head(300000).plot(x="LMST", y="UPWARD_LW_IRRADIANCE")
data_tirs.head(300000).plot(x="LMST", y="DOWNWARD_LW_IRRADIANCE")
# Out:
# <Axes: xlabel='LMST'>
